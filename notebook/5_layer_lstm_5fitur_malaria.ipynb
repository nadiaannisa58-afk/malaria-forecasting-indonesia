# %%
import pandas as pd
import numpy as np
import math
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
import os
from google.colab import drive

drive.mount('/content/drive')

# Load main malaria dataset
# !cp "/content/drive/MyDrive/hasil_data_gabungan.csv" "./data.csv"
df = pd.read_csv("data.csv")

# Clean numeric columns
for col in ["Kasus Malaria", "Curah Hujan", "Kelembapan", "Suhu"]:
    df[col] = df[col].astype(str).str.replace(",", "").str.strip()
    df[col] = pd.to_numeric(df[col], errors='coerce')

df.dropna(inplace=True)

# Load DMI & ONI data
# !cp "/content/drive/MyDrive/DATA/ONI (Tahun).xlsx" "./ONI_3.xlsx"
# !cp "/content/drive/MyDrive/DATA/DMI pertahun (Tahun).xlsx" "./DMI_pertahun.xlsx"

dmi_df = pd.read_excel("DMI_pertahun.xlsx")
oni_df = pd.read_excel("ONI_3.xlsx")

# Merge DMI and ONI into main dataframe based on "Tahun"
df = df.merge(dmi_df, on="Tahun", how="left")
df = df.merge(oni_df, on="Tahun", how="left")
print (df)
# Drop missing rows after merging
df.dropna(inplace=True)

# Sequence preparation function
def create_sequences(data, n_steps=2):
    X, y = [], []
    for i in range(len(data) - n_steps):
        X.append(data[i:i+n_steps, 1:])  # All features except target
        y.append(data[i+n_steps, 0])     # Target: Kasus Malaria
    return np.array(X), np.array(y)

# Inverse transform function
def inverse_scale(preds, scaler):
    dummy = np.zeros((len(preds), 5))  # 5 dummy features to pad back to 6 columns
    return scaler.inverse_transform(np.hstack((preds, dummy)))[:, 0]

# Set parameters
n_steps = 2
performance_results = []
provinces = df["Nama Provinsi"].unique()

training_histories = {}

for province in provinces:
    print(f"\nProcessing: {province}")
    df_prov = df[df["Nama Provinsi"] == province].sort_values("Tahun").copy()

    if len(df_prov) < 5:
        print(f"Skipping {province} due to insufficient data.")
        continue

    # Normalize 6 features: target + 5 inputs
    scaler = MinMaxScaler()
    scaled = scaler.fit_transform(df_prov[["Kasus Malaria", "Curah Hujan", "Kelembapan", "Suhu", "DMI", "ONI"]])

    X, y = create_sequences(scaled, n_steps)
    if len(X) < 1:
        print(f"Skipping {province} due to insufficient sequences.")
        continue

    # Split into train and test
    split = int(len(X) * 0.8)
    X_train, X_test = X[:split], X[split:]
    y_train, y_test = y[:split], y[split:]

    # Define 5-layer LSTM
    model = Sequential()
    model.add(LSTM(8, return_sequences=True, input_shape=(n_steps, X.shape[2])))
    model.add(Dropout(0.2))
    model.add(LSTM(24, return_sequences=True))
    model.add(Dropout(0.2))
    model.add(LSTM(16, return_sequences=True))
    model.add(Dropout(0.2))
    model.add(LSTM(16, return_sequences=True))
    model.add(Dropout(0.2))
    model.add(LSTM(8))
    model.add(Dropout(0.2))
    model.add(Dense(1, activation='linear'))
    model.compile(optimizer=Adam(learning_rate=0.001), loss='mse')

    # Train the model
    early_stop = EarlyStopping(monitor='val_loss', patience=550, restore_best_weights=True)
    history = model.fit(X_train, y_train, epochs=4000, batch_size=1, verbose=0,
              callbacks=[early_stop], validation_data=(X_test, y_test))
    training_histories[province] = history.history

    # Predict and inverse transform
    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)
    y_train_inv = inverse_scale(y_train.reshape(-1, 1), scaler)
    y_train_pred_inv = inverse_scale(y_train_pred, scaler)
    y_test_inv = inverse_scale(y_test.reshape(-1, 1), scaler)
    y_test_pred_inv = inverse_scale(y_test_pred, scaler)

    # Calculate metrics
    train_rmse = math.sqrt(mean_squared_error(y_train_inv, y_train_pred_inv))
    train_mae = mean_absolute_error(y_train_inv, y_train_pred_inv)
    test_rmse = math.sqrt(mean_squared_error(y_test_inv, y_test_pred_inv))
    test_mae = mean_absolute_error(y_test_inv, y_test_pred_inv)
    train_r2 = r2_score(y_train_inv, y_train_pred_inv)
    test_r2 = r2_score(y_test_inv, y_test_pred_inv)

    performance_results.append({
        'Province': province,
        'Model': 'LSTM_5Layers_6Features',
        'Train RMSE': train_rmse,
        'Train MAE': train_mae,
        'Train R2': train_r2,
        'Test RMSE': test_rmse,
        'Test MAE': test_mae,
        'Test R2': test_r2
    })

# Save results
performance_df = pd.DataFrame(performance_results)
performance_df.to_csv("performance_results_gabungan.csv", index=False)
print("\nPerformance Summary:")
print(performance_df)

# summary plot (RMSE test comparison between provinces)
plt.figure(figsize=(10, 6))
plt.barh(performance_df['Province'], performance_df['Test RMSE'], color='skyblue')
plt.xlabel('Test RMSE')
plt.title('Test RMSE for Malaria Prediction by Province')
plt.tight_layout()
# plt.savefig('plots/test_rmse_by_province.png')
plt.show()

# Summary plot (RMSE train comparison between provinces)
plt.figure(figsize=(10, 6))
plt.barh(performance_df['Province'], performance_df['Train RMSE'], color='Lightgreen')
plt.xlabel('train RMSE')
plt.title('train RMSE for Malaria Prediction by Province')
plt.tight_layout()
# plt.savefig('plots/Train_rmse_by_province.png')
plt.show()

# Summary plot (MAE test comparison between provinces)
plt.figure(figsize=(10, 6))
plt.barh(performance_df['Province'], performance_df['Test MAE'], color='coral')
plt.xlabel('Test MAE')
plt.title('Test MAE for Malaria Prediction by Province')
plt.tight_layout()
# plt.savefig('plots/test_mae_by_province.png')
plt.show()

# Summary plot (MAE train comparison between provinces)
plt.figure(figsize=(10, 6))
plt.barh(performance_df['Province'], performance_df['Train MAE'], color='seagreen')
plt.xlabel('train MAE')
plt.title('train MAE for Malaria Prediction by Province')
plt.tight_layout()
# plt.savefig('plots/Train_mae_by_province.png')
plt.show()

# Summary plot (R2 test comparison between provinces)
plt.figure(figsize=(10, 6))
plt.barh(performance_df['Province'], performance_df['Test R2'], color='mediumslateblue')
plt.xlabel('Test R2')
plt.title('Test R2 for Malaria Prediction by Province')
plt.tight_layout()
# plt.savefig('plots/test_R2_by_province.png')
plt.show()

# Summary plot (R2 train comparison between provinces)
plt.figure(figsize=(10, 6))
plt.barh(performance_df['Province'], performance_df['Train R2'], color='darkorange')
plt.xlabel('train R2')
plt.title('train R2 for Malaria Prediction by Province')
plt.tight_layout()
# plt.savefig('plots/Train_R2_by_province.png')
plt.show()
# Out:
# Mounted at /content/drive
#       Nama Provinsi  Tahun  Kasus Malaria  Curah Hujan  Kelembapan     Suhu  \
# 0              ACEH   2010         2354.0     1855.280     78.4900  27.0000
# 1    SUMATERA UTARA   2010         5377.0     2135.870     85.1700  25.8700
# 2    SUMATERA BARAT   2010          260.0     4282.600     87.0800  23.7700
# 3              RIAU   2010         1005.0     3547.690     90.7500  26.0400
# 4             JAMBI   2010         2309.0     3080.550     90.4700  26.1000
# ..              ...    ...            ...          ...         ...      ...
# 457  SULAWESI BARAT   2023          321.0     1761.850     77.1100  28.4300
# 458          MALUKU   2023         1668.0     2139.040     85.8600  26.7200
# 459    MALUKU UTARA   2023          244.0     1961.700     80.9100  27.4900
# 460     PAPUA BARAT   2023        15610.0     2347.205     80.3550  27.9850
# 461           PAPUA   2023       344399.0     2446.490     87.0275  22.9725
#
#           DMI     ONI
# 0   -0.041667 -0.2100
# 1   -0.041667 -0.2100
# 2   -0.041667 -0.2100
# 3   -0.041667 -0.2100
# 4   -0.041667 -0.2100
# ..        ...     ...
# 457  0.599417  0.5825
# 458  0.599417  0.5825
# 459  0.599417  0.5825
# 460  0.599417  0.5825
# 461  0.599417  0.5825
#
# [462 rows x 8 columns]
#
# Processing: ACEH
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 722ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 678ms/step
#
# Processing: SUMATERA UTARA
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 675ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 928ms/step
#
# Processing: SUMATERA BARAT
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7b769eba3740> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 665ms/step
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7b769eba3740> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 739ms/step
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Processing: RIAU
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 679ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 725ms/step
#
# Processing: JAMBI
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 731ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 783ms/step
#
# Processing: SUMATERA SELATAN
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 675ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processing: BENGKULU
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 677ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 715ms/step
#
# Processing: LAMPUNG
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 690ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 715ms/step
#
# Processing: KEP. BANGKA BELITUNG
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 681ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 704ms/step
#
# Processing: KEP. RIAU
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 884ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processing: DKI JAKARTA
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 648ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 703ms/step
#
# Processing: JAWA BARAT
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 668ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 715ms/step
#
# Processing: JAWA TENGAH
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 782ms/step
#
# Processing: DI YOGYAKARTA
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 658ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 728ms/step
#
# Processing: JAWA TIMUR
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 694ms/step
#
# Processing: BANTEN
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 663ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 709ms/step
#
# Processing: BALI
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 705ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 773ms/step
#
# Processing: NUSA TENGGARA BARAT
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 711ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 726ms/step
#
# Processing: NUSA TENGGARA TIMUR
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 972ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 849ms/step
#
# Processing: KALIMANTAN BARAT
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 658ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 727ms/step
#
# Processing: KALIMANTAN TENGAH
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 703ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 750ms/step
#
# Processing: KALIMANTAN SELATAN
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 946ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processing: KALIMANTAN TIMUR
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 968ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 875ms/step
#
# Processing: SULAWESI UTARA
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 640ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 736ms/step
#
# Processing: SULAWESI TENGAH
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 669ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 908ms/step
#
# Processing: SULAWESI SELATAN
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 739ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 789ms/step
#
# Processing: SULAWESI TENGGARA
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 669ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 738ms/step
#
# Processing: GORONTALO
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 669ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 903ms/step
#
# Processing: SULAWESI BARAT
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 674ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 743ms/step
#
# Processing: MALUKU
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 670ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 744ms/step
#
# Processing: MALUKU UTARA
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 677ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 688ms/step
#
# Processing: PAPUA BARAT
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 752ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 723ms/step
#
# Processing: PAPUA
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 899ms/step
#
# Performance Summary:
#                 Province                   Model    Train RMSE     Train MAE  \
# 0                   ACEH  LSTM_5Layers_6Features    316.481620    248.088907
# 1         SUMATERA UTARA  LSTM_5Layers_6Features   3197.121017   2508.775980
# 2         SUMATERA BARAT  LSTM_5Layers_6Features    690.753723    583.480003
# 3                   RIAU  LSTM_5Layers_6Features    170.989725    109.808971
# 4                  JAMBI  LSTM_5Layers_6Features   2016.700053   1339.268372
# 5       SUMATERA SELATAN  LSTM_5Layers_6Features   1774.681221   1479.658228
# 6               BENGKULU  LSTM_5Layers_6Features   4285.550509   3010.326172
# 7                LAMPUNG  LSTM_5Layers_6Features   2402.449587   2083.733850
# 8   KEP. BANGKA BELITUNG  LSTM_5Layers_6Features   1301.582471    806.218025
# 9              KEP. RIAU  LSTM_5Layers_6Features   1463.542210    815.971784
# 10           DKI JAKARTA  LSTM_5Layers_6Features     34.836531     29.111695
# 11            JAWA BARAT  LSTM_5Layers_6Features     79.749974     61.662230
# 12           JAWA TENGAH  LSTM_5Layers_6Features    660.272423    519.251819
# 13         DI YOGYAKARTA  LSTM_5Layers_6Features     47.854557     40.407279
# 14            JAWA TIMUR  LSTM_5Layers_6Features    235.665008    198.333526
# 15                BANTEN  LSTM_5Layers_6Features     44.611853     35.499458
# 16                  BALI  LSTM_5Layers_6Features     21.087158     17.204803
# 17   NUSA TENGGARA BARAT  LSTM_5Layers_6Features   1876.333857   1490.830750
# 18   NUSA TENGGARA TIMUR  LSTM_5Layers_6Features  42501.276864  31687.806749
# 19      KALIMANTAN BARAT  LSTM_5Layers_6Features   1304.969988    681.439297
# 20     KALIMANTAN TENGAH  LSTM_5Layers_6Features   3091.003388   1861.752143
# 21    KALIMANTAN SELATAN  LSTM_5Layers_6Features   3489.417438   2498.167967
# 22      KALIMANTAN TIMUR  LSTM_5Layers_6Features    767.371162    547.558450
# 23        SULAWESI UTARA  LSTM_5Layers_6Features   1717.003502   1145.402067
# 24       SULAWESI TENGAH  LSTM_5Layers_6Features   2522.954649   1622.709871
# 25      SULAWESI SELATAN  LSTM_5Layers_6Features    307.295307    281.894910
# 26     SULAWESI TENGGARA  LSTM_5Layers_6Features    675.499048    558.283622
# 27             GORONTALO  LSTM_5Layers_6Features    439.131541    263.758385
# 28        SULAWESI BARAT  LSTM_5Layers_6Features    432.618222    216.744536
# 29                MALUKU  LSTM_5Layers_6Features   7247.862730   5683.499886
# 30          MALUKU UTARA  LSTM_5Layers_6Features   2943.935939   2257.278001
# 31           PAPUA BARAT  LSTM_5Layers_6Features  13400.126540   9960.427080
# 32                 PAPUA  LSTM_5Layers_6Features  11054.467207   9987.931065
#
#     Train R2      Test RMSE       Test MAE     Test R2
# 0   0.819015      26.890046      25.584843    0.892920
# 1   0.644616     878.017251     803.602751    0.469073
# 2  -2.356965      63.344652      61.085711   -0.009812
# 3   0.913444     947.600430     830.460811   -0.814627
# 4  -0.661490     100.215965      75.976753   -0.123545
# 5  -2.231143      54.147420      53.095092  -24.819460
# 6  -0.914258     189.669655     189.325675 -288.598572
# 7  -2.269115     282.620345     245.974356   -0.014471
# 8  -0.549726      82.195670      78.033707   -9.043798
# 9  -0.450593      86.381235      85.323979  -44.436712
# 10  0.096405     137.192472     119.277565   -3.544127
# 11  0.672237      50.068467      49.494214    0.830900
# 12 -0.325041     154.440775     146.633282   -0.047077
# 13  0.355119      32.793655      32.133234    0.566517
# 14  0.322791     149.045806     119.745972    0.229532
# 15  0.499277       7.669372       6.241115    0.970914
# 16  0.032759      23.963987      19.293035   -2.109780
# 17 -1.471842      78.575208      76.362826   -0.291585
# 18 -1.251050    3744.152442    3379.150994   -0.001869
# 19 -0.296909     111.961562     110.810194  -54.961568
# 20 -0.517227     141.354480     137.350608  -16.773256
# 21 -1.051721     129.194174     113.088578   -1.134962
# 22  0.209074     756.516077     656.158409   -0.387570
# 23 -0.383390     214.061762     193.433047   -0.011027
# 24 -0.585271     253.260259     244.037161   -0.022692
# 25  0.473576     366.559134     228.497688    0.136173
# 26 -1.763925     111.828000     108.264332   -0.005786
# 27  0.461323     378.884816     308.625218    0.719846
# 28 -0.166924      94.583609      86.001733   -0.002821
# 29 -1.491427     367.284685     290.807528   -0.069316
# 30 -1.383424      83.334973      65.153592   -1.559898
# 31 -0.273523    3349.178360    3047.360240   -0.011172
# 32  0.927648  121570.136152  107289.677821   -5.250905

# %%
import pandas as pd
import numpy as np
import math
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
import os
from google.colab import drive

drive.mount('/content/drive')

# Load main malaria dataset
# !cp "/content/drive/MyDrive/hasil_data_gabungan.csv" "./data.csv"
df = pd.read_csv("data.csv")

# Buat folder tujuan kalau belum ada
save_dir = "/content/drive/MyDrive/DATA/plot model loss Malaria"
os.makedirs(save_dir, exist_ok=True)

# Clean numeric columns
for col in ["Kasus Malaria", "Curah Hujan", "Kelembapan", "Suhu"]:
    df[col] = df[col].astype(str).str.replace(",", "").str.strip()
    df[col] = pd.to_numeric(df[col], errors='coerce')

df.dropna(inplace=True)

# Load DMI & ONI data
# !cp "/content/drive/MyDrive/DATA/ONI (Tahun).xlsx" "./ONI_3.xlsx"
# !cp "/content/drive/MyDrive/DATA/DMI pertahun (Tahun).xlsx" "./DMI_pertahun.xlsx"

dmi_df = pd.read_excel("DMI_pertahun.xlsx")
oni_df = pd.read_excel("ONI_3.xlsx")

# Merge DMI and ONI into main dataframe based on "Tahun"
df = df.merge(dmi_df, on="Tahun", how="left")
df = df.merge(oni_df, on="Tahun", how="left")
print (df)
# Drop missing rows after merging
df.dropna(inplace=True)

# Sequence preparation function
def create_sequences(data, n_steps=2):
    X, y = [], []
    for i in range(len(data) - n_steps):
        X.append(data[i:i+n_steps, 1:])  # All features except target
        y.append(data[i+n_steps, 0])     # Target: Kasus Malaria
    return np.array(X), np.array(y)

# Inverse transform function
def inverse_scale(preds, scaler):
    dummy = np.zeros((len(preds), 5))  # 5 dummy features to pad back to 6 columns
    return scaler.inverse_transform(np.hstack((preds, dummy)))[:, 0]

# Set parameters
n_steps = 2
performance_results = []
provinces = df["Nama Provinsi"].unique()

training_histories = {}

for province in provinces:
  # if province  == "JAWA BARAT":
    print(f"\nProcessing: {province}")
    df_prov = df[df["Nama Provinsi"] == province].sort_values("Tahun").copy()

    if len(df_prov) < 5:
        print(f"Skipping {province} due to insufficient data.")
        continue

    # Normalize 6 features: target + 5 inputs
    scaler = MinMaxScaler()
    scaled = scaler.fit_transform(df_prov[["Kasus Malaria", "Curah Hujan", "Kelembapan", "Suhu", "DMI", "ONI"]])

    X, y = create_sequences(scaled, n_steps)
    if len(X) < 1:
        print(f"Skipping {province} due to insufficient sequences.")
        continue

    # Split into train and test
    split = int(len(X) * 0.8)
    X_train, X_test = X[:split], X[split:]
    y_train, y_test = y[:split], y[split:]

    # Define 5-layer LSTM
    model = Sequential()
    model.add(LSTM(8, return_sequences=True, input_shape=(n_steps, X.shape[2])))
    model.add(Dropout(0.2))
    model.add(LSTM(24, return_sequences=True))
    model.add(Dropout(0.2))
    model.add(LSTM(16, return_sequences=True))
    model.add(Dropout(0.2))
    model.add(LSTM(16, return_sequences=True))
    model.add(Dropout(0.2))
    model.add(LSTM(8))
    model.add(Dropout(0.2))
    model.add(Dense(1, activation='linear'))
    model.compile(optimizer=Adam(learning_rate=0.0095), loss='mse')

    # Train the model
    early_stop = EarlyStopping(monitor='val_loss', patience=550, restore_best_weights=True)
    history = model.fit(X_train, y_train, epochs=4000, batch_size=1, verbose=0,
              callbacks=[early_stop], validation_data=(X_test, y_test))
    training_histories[province] = history.history

    # Predict and inverse transform
    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)
    y_train_inv = inverse_scale(y_train.reshape(-1, 1), scaler)
    y_train_pred_inv = inverse_scale(y_train_pred, scaler)
    y_test_inv = inverse_scale(y_test.reshape(-1, 1), scaler)
    y_test_pred_inv = inverse_scale(y_test_pred, scaler)

    # Calculate metrics
    train_rmse = math.sqrt(mean_squared_error(y_train_inv, y_train_pred_inv))
    train_mae = mean_absolute_error(y_train_inv, y_train_pred_inv)
    test_rmse = math.sqrt(mean_squared_error(y_test_inv, y_test_pred_inv))
    test_mae = mean_absolute_error(y_test_inv, y_test_pred_inv)
    train_r2 = r2_score(y_train_inv, y_train_pred_inv)
    test_r2 = r2_score(y_test_inv, y_test_pred_inv)

    performance_results.append({
        'Province': province,
        'Model': 'LSTM_5Layers_6Features',
        'Train RMSE': train_rmse,
        'Train MAE': train_mae,
        'Train R2': train_r2,
        'Test RMSE': test_rmse,
        'Test MAE': test_mae,
        'Test R2': test_r2
    })
    # ⬇️ Tambahkan ini di akhir loop provinsi
    test_loss = model.evaluate(X_test, y_test, verbose=0)
    print(f"Final test loss for {province}: {test_loss:.4f}")
# Convert performance results to DataFrame
performance_df = pd.DataFrame(performance_results)

# Save to CSV for further analysis
# performance_df.to_csv('performance_DBD_results_provinces.csv', index=False)

# Print performance summary in table format
print("\nPerformance Results DBD Summary:")
print(performance_df)

# Loop untuk setiap provinsi yang ada di training_histories
for prov, hist in training_histories.items():
    plt.figure(figsize=(6, 4))
    plt.plot(hist['loss'], label='Train')
    plt.plot(hist['val_loss'], label='Validation')
    plt.title(f"Model loss - {prov}")
    plt.xlabel("Epoch")
    plt.ylabel("Loss (MSE)")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    save_path = os.path.join(save_dir, f"model_loss_{prov}.png")
    plt.savefig(save_path, dpi=600)
    plt.show()
# Out:
# Mounted at /content/drive
#       Nama Provinsi  Tahun  Kasus Malaria  Curah Hujan  Kelembapan     Suhu  \
# 0              ACEH   2010         2354.0     1855.280     78.4900  27.0000
# 1    NORTH SUMATERA   2010         5377.0     2135.870     85.1700  25.8700
# 2     WEST SUMATERA   2010          260.0     4282.600     87.0800  23.7700
# 3              RIAU   2010         1005.0     3547.690     90.7500  26.0400
# 4             JAMBI   2010         2309.0     3080.550     90.4700  26.1000
# ..              ...    ...            ...          ...         ...      ...
# 457   WEST SULAWESI   2023          321.0     1761.850     77.1100  28.4300
# 458          MALUKU   2023         1668.0     2139.040     85.8600  26.7200
# 459    NORTH MALUKU   2023          244.0     1961.700     80.9100  27.4900
# 460     WEST PAPUA    2023        15610.0     2347.205     80.3550  27.9850
# 461           PAPUA   2023       344399.0     2446.490     87.0275  22.9725
#
#           DMI     ONI
# 0   -0.041667 -0.2100
# 1   -0.041667 -0.2100
# 2   -0.041667 -0.2100
# 3   -0.041667 -0.2100
# 4   -0.041667 -0.2100
# ..        ...     ...
# 457  0.599417  0.5825
# 458  0.599417  0.5825
# 459  0.599417  0.5825
# 460  0.599417  0.5825
# 461  0.599417  0.5825
#
# [462 rows x 8 columns]
#
# Processing: ACEH
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 729ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 692ms/step
# Final test loss for ACEH: 0.0001
#
# Processing: NORTH SUMATERA
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 716ms/step
# Final test loss for NORTH SUMATERA: 0.0034
#
# Processing: WEST SUMATERA
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x782d0d6268e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 659ms/step
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x782d0d6268e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 693ms/step
# Final test loss for WEST SUMATERA: 0.0636
#
# Processing: RIAU
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 658ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 676ms/step
# Final test loss for RIAU: 0.1606
#
# Processing: JAMBI
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 646ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 675ms/step
# Final test loss for JAMBI: 0.0171
#
# Processing: SOUTH SUMATERA
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 673ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 697ms/step
# Final test loss for SOUTH SUMATERA: 0.0234
#
# Processing: BENGKULU
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 947ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1000ms/step
# Final test loss for BENGKULU: 0.0023
#
# Processing: LAMPUNG
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 664ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 731ms/step
# Final test loss for LAMPUNG: 0.0485
#
# Processing: BANGKA BELITUNG ISLANDS
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 674ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 717ms/step
# Final test loss for BANGKA BELITUNG ISLANDS: 0.0070
#
# Processing: RIAU ISLANDS
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 964ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 681ms/step
# Final test loss for RIAU ISLANDS: 0.0044
#
# Processing: JAKARTA
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 688ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 943ms/step
# Final test loss for JAKARTA: 0.2382
#
# Processing: WEST JAVA
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 640ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 698ms/step
# Final test loss for WEST JAVA: 0.0002
#
# Processing: CENTRAL JAVA
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 649ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 686ms/step
# Final test loss for CENTRAL JAVA: 0.0060
#
# Processing: YOGYAKARTA
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 713ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Final test loss for YOGYAKARTA: 0.0270
#
# Processing: EAST JAVA
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 662ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 730ms/step
# Final test loss for EAST JAVA: 0.0009
#
# Processing: BANTEN
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 638ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 692ms/step
# Final test loss for BANTEN: 0.0031
#
# Processing: BALI
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 660ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Final test loss for BALI: 0.1126
#
# Processing: WEST NUSA TENGGARA
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 680ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 710ms/step
# Final test loss for WEST NUSA TENGGARA: 0.0211
#
# Processing: EAST NUSA TENGGARA
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 656ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 696ms/step
# Final test loss for EAST NUSA TENGGARA: 0.0416
#
# Processing: WEST KALIMANTAN
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 628ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 681ms/step
# Final test loss for WEST KALIMANTAN: 0.0007
#
# Processing: CENTRAL KALIMANTAN
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 785ms/step
# Final test loss for CENTRAL KALIMANTAN: 0.0007
#
# Processing: SOUTH KALIMANTAN
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 654ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 714ms/step
# Final test loss for SOUTH KALIMANTAN: 0.0533
#
# Processing: EAST KALIMANTAN
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 636ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 687ms/step
# Final test loss for EAST KALIMANTAN: 0.0463
#
# Processing: NORTH SULAWESI
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 654ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 681ms/step
# Final test loss for NORTH SULAWESI: 0.0014
#
# Processing: CENTRAL SULAWESI
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 910ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Final test loss for CENTRAL SULAWESI: 0.0015
#
# Processing: SOUTH SULAWESI
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 687ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Final test loss for SOUTH SULAWESI: 0.0178
#
# Processing: SOUTHEAST SULAWESI
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 934ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 693ms/step
# Final test loss for SOUTHEAST SULAWESI: 0.0128
#
# Processing: GORONTALO
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 647ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 676ms/step
# Final test loss for GORONTALO: 0.0071
#
# Processing: WEST SULAWESI
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 632ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 697ms/step
# Final test loss for WEST SULAWESI: 0.0009
#
# Processing: MALUKU
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 651ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 676ms/step
# Final test loss for MALUKU: 0.0013
#
# Processing: NORTH MALUKU
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 751ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 782ms/step
# Final test loss for NORTH MALUKU: 0.0257
#
# Processing: WEST PAPUA
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 670ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 745ms/step
# Final test loss for WEST PAPUA : 0.0181
#
# Processing: PAPUA
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 980ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Final test loss for PAPUA: 0.0959
#
# Performance Results DBD Summary:
#                    Province                   Model    Train RMSE  \
# 0                      ACEH  LSTM_5Layers_6Features    531.397755
# 1            NORTH SUMATERA  LSTM_5Layers_6Features   3735.199729
# 2             WEST SUMATERA  LSTM_5Layers_6Features    468.184461
# 3                      RIAU  LSTM_5Layers_6Features    427.629301
# 4                     JAMBI  LSTM_5Layers_6Features   1494.124212
# 5            SOUTH SUMATERA  LSTM_5Layers_6Features    763.874439
# 6                  BENGKULU  LSTM_5Layers_6Features    979.510920
# 7                   LAMPUNG  LSTM_5Layers_6Features   1157.294425
# 8   BANGKA BELITUNG ISLANDS  LSTM_5Layers_6Features   1079.038912
# 9              RIAU ISLANDS  LSTM_5Layers_6Features   1247.415335
# 10                  JAKARTA  LSTM_5Layers_6Features     33.838195
# 11                WEST JAVA  LSTM_5Layers_6Features     86.606414
# 12             CENTRAL JAVA  LSTM_5Layers_6Features    651.933886
# 13               YOGYAKARTA  LSTM_5Layers_6Features     51.203034
# 14                EAST JAVA  LSTM_5Layers_6Features     83.186789
# 15                   BANTEN  LSTM_5Layers_6Features     43.267038
# 16                     BALI  LSTM_5Layers_6Features     19.392929
# 17       WEST NUSA TENGGARA  LSTM_5Layers_6Features    884.359727
# 18       EAST NUSA TENGGARA  LSTM_5Layers_6Features  28976.987498
# 19          WEST KALIMANTAN  LSTM_5Layers_6Features   1267.824254
# 20       CENTRAL KALIMANTAN  LSTM_5Layers_6Features    336.628506
# 21         SOUTH KALIMANTAN  LSTM_5Layers_6Features   2580.745646
# 22          EAST KALIMANTAN  LSTM_5Layers_6Features    585.485793
# 23           NORTH SULAWESI  LSTM_5Layers_6Features    609.290376
# 24         CENTRAL SULAWESI  LSTM_5Layers_6Features   2322.588705
# 25           SOUTH SULAWESI  LSTM_5Layers_6Features    269.635276
# 26       SOUTHEAST SULAWESI  LSTM_5Layers_6Features    407.728035
# 27                GORONTALO  LSTM_5Layers_6Features    692.245853
# 28            WEST SULAWESI  LSTM_5Layers_6Features    398.943823
# 29                   MALUKU  LSTM_5Layers_6Features   4043.244239
# 30             NORTH MALUKU  LSTM_5Layers_6Features   1883.002255
# 31              WEST PAPUA   LSTM_5Layers_6Features  12216.679551
# 32                    PAPUA  LSTM_5Layers_6Features  22081.211128
#
#        Train MAE  Train R2      Test RMSE      Test MAE      Test R2
# 0     308.713106  0.489747      25.823099     16.702601     0.901249
# 1    2847.702753  0.514926     962.024973    748.368039     0.362616
# 2     370.646239 -0.542177     311.607802    305.067940   -23.436407
# 3     283.550178  0.458632    1019.863345    953.110235    -1.101942
# 4     951.145391  0.088013     652.685930    477.998702   -46.656809
# 5     625.876185  0.401369     467.538182    431.300485 -1923.978050
# 6     711.411861  0.899999     452.444756    449.883439 -1646.903679
# 7     881.572523  0.241406     873.104080    780.980414    -8.681994
# 8     787.657424 -0.065089     462.080113    453.575308  -316.420264
# 9     655.801275 -0.053798     283.673222    266.606560  -489.009793
# 10     27.365525  0.147453     129.335971    110.859017    -3.038579
# 11     79.206437  0.613456       6.228479      5.912039     0.997383
# 12    512.373371 -0.291785     154.984327    145.946557    -0.054461
# 13     40.601420  0.261715      33.538318     33.252127     0.546607
# 14     72.468168  0.915620      28.239957     22.278446     0.972341
# 15     35.137395  0.529011      12.389614     11.167347     0.924092
# 16     15.969545  0.181939      23.487093     18.920564    -1.987239
# 17    682.686026  0.450891    1115.487567    827.120136  -259.304323
# 18  21089.763927 -0.046376   17688.559340  15713.267022   -21.360872
# 19    657.779782 -0.224127     223.026425    218.940374  -221.057081
# 20    260.951951  0.982005     212.457514    140.945904   -39.150599
# 21   1991.514347 -0.122284    1758.414183   1756.461129  -394.500184
# 22    446.397416  0.539577     652.361864    632.551601    -0.031801
# 23    500.328644  0.825799     210.709423    195.953839     0.020392
# 24   1498.956791 -0.343474     313.062523    257.969005    -0.562691
# 25    216.552054  0.594699     317.114728    277.395291     0.353496
# 26    308.951688 -0.006973     315.100880    312.431792    -6.985533
# 27    436.832054 -0.338627     170.089099    104.995751     0.943541
# 28    199.069174  0.007669      63.020332     52.695867     0.554802
# 29   2791.051821  0.224667     463.844308    330.272748    -0.705473
# 30   1365.738236  0.024906    1019.011402    826.588824  -381.759589
# 31   9975.148348 -0.058511    4689.065884   3449.402632    -0.982081
# 32  17125.248178  0.711317  106055.690557  90159.109079    -3.757261
